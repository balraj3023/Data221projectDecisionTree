# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

df = pd.read_csv("Data221projectDecisionTree/train.csv")
df.head()

# seperating input and target variable
X = df.drop("price_range", axis=1)
y = df["price_range"]

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=42, stratify=y)
# decision tree
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

y_prediction = model.predict(X_test)
accuracy = accuracy_score(y_test, y_prediction)
accuracy_percentage = round(accuracy * 100,2)
print("Model Accuracy is:", accuracy_percentage, "%")

print(classification_report(y_test, y_prediction))

print(confusion_matrix(y_test, y_prediction))

# features importance
feature_importance_df = pd.DataFrame({"Feature": X.columns,"Importance": model.feature_importances_}).sort_values(by="Importance", ascending=False)

print(feature_importance_df)
# Out:
# Model Accuracy is: 82.4 %
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88       125
#            1       0.80      0.74      0.77       125
#            2       0.76      0.79      0.77       125
#            3       0.88      0.86      0.87       125
#
#     accuracy                           0.82       500
#    macro avg       0.82      0.82      0.82       500
# weighted avg       0.82      0.82      0.82       500
#
# [[113  12   0   0]
#  [ 18  93  14   0]
#  [  0  11  99  15]
#  [  0   0  18 107]]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/lp/hc78tc8x72z4nxhzd4lzh7rh0000gp/T/ipykernel_76485/1587875669.py in ?()
# ---> 28 import pandas as pd
#      29 from sklearn.model_selection import train_test_split
#      30 from sklearn.tree import DecisionTreeClassifier
#      31 from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
#
# ~/PyCharmMiscProject/.venv/lib/python3.8/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6754         elif len(by):
#    6755             # len(by) == 1
#    6756
#    6757             by = by[0]
# -> 6758             k = self._get_label_or_level_values(by, axis=axis)
#    6759
#    6760             # need to rewrap column in Series to apply key function
#    6761             if key is not None:
#
# ~/PyCharmMiscProject/.venv/lib/python3.8/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1774             values = self.xs(key, axis=other_axes[0])._values
#    1775         elif self._is_level_reference(key, axis=axis):
#    1776             values = self.axes[axis].get_level_values(key)._values
#    1777         else:
# -> 1778             raise KeyError(key)
#    1779
#    1780         # Check for duplicates
#    1781         if values.ndim > 1:
#
# KeyError: '...'
